# %%
import time
import pandas as pd
from bs4 import BeautifulSoup
import requests
import os

# %%
# URL of the webpage to scrape
url = 'https://www.justsunnies.com.au/new?filter.ss_is_polarised.high=0&filter.ss_is_polarised.low=0&resultsPerPage=100'

# Send an HTTP request to the website and get the response
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all product containers (adjust selector as per your HTML structure)
    products = soup.find_all('h3', class_='prod-detail-wrapper')
    
    # Print number of products found for debugging
    print(f"Found {len(products)} products.")
    
    # Initialize lists to store product details
    brands = []
    product_names = []
    descriptions = []
    prices = []
    
    # Iterate over each product and extract details
    for idx, product in enumerate(products):
        # print(f"\nProduct {idx + 1}:")
        
        # Extract the brand name
        brand_name = product.find('p', class_='brand-name')
        if brand_name:
            brand_name = brand_name.text.strip()
        else:
            brand_name = "Brand not found"
        brands.append(brand_name)
        
        # Extract the product name
        prod_name = product.find('p', class_='prod-name')
        if prod_name:
            prod_name = prod_name.text.strip()
        else:
            prod_name = "Product name not found"
        product_names.append(prod_name)
        
        # Extract the product description
        prod_desc = product.find('p', class_='prod-desc')
        if prod_desc:
            prod_desc = prod_desc.text.strip()
        else:
            prod_desc = "Product description not found"
        descriptions.append(prod_desc)
        
        # Extract the price
        price_wrapper = product.find_next('div', class_='price-wrapper')
        if price_wrapper:
            price = price_wrapper.find('span').text.strip()
        else:
            price = "Price not found"
        prices.append(price)
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# Found 100 products.

# %%
prod = pd.DataFrame({
    'Brand': brands,
    'Product Name': product_names,
    'Description': descriptions,
    'Price': prices
})

# %%
# Save the DataFrame to a CSV file in the data folder outside this working directory
file_name = 'prod_no_polarized_no_prescribed_glasses.csv'

# if file is already in the directory, add one to the file name
i = 1
base_name, extension = os.path.splitext(file_name)
while file_name in os.listdir():
    file_name = f"{base_name}_{i}{extension}"
    i += 1

prod.to_csv(file_name, index=False)

# %% [markdown]
# ---

# %% [markdown]
# 1. Preprocess the polarized and prescribed dataset

# %%
df1 = pd.read_csv('prod_polarized_prescribed.csv')
df2 = pd.read_csv('prod_polarized_prescribed_1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df1 = pd.read_csv('prod_polarized_prescribed.csv')
#       2 df2 = pd.read_csv('prod_polarized_prescribed_1.csv')
#
# File c:\Users\ayush\OneDrive - Sujal Dhungana\fake-data-generator\fakedata\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\ayush\OneDrive - Sujal Dhungana\fake-data-generator\fakedata\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\ayush\OneDrive - Sujal Dhungana\fake-data-generator\fakedata\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\ayush\OneDrive - Sujal Dhungana\fake-data-generator\fakedata\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\ayush\OneDrive - Sujal Dhungana\fake-data-generator\fakedata\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prod_polarized_prescribed.csv'

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df.head()
# Out:
#      Brand Product Name                           Description    Price
# 0  Miu Miu       MU56ZS        Gold/Light Purple Brown Lenses  $538.20
# 1  Miu Miu         01YS        Honey Havana/Dark Brown Lenses  $509.40
# 2    Prada       PRA60S                   Brass/Violet Lenses  $501.30
# 3    Prada       PRA51S  Pale Gold/Brown Grey Gradient Lenses  $592.20
# 4    Prada       PRA51S           Silver/Grey Gradient Lenses  $592.20

# %%
df['Polarized'] = 'Yes'
df['Prescription'] = 'Prescribed Sunglasses'

# %%
df
# Out:
#                Brand       Product Name  \
# 0            Miu Miu             MU56ZS
# 1            Miu Miu               01YS
# 2              Prada             PRA60S
# 3              Prada             PRA51S
# 4              Prada             PRA51S
# ..               ...                ...
# 195     Michael Kors      Cadiz MK1145B
# 196     Michael Kors  CATALONIA MK1144B
# 197     Michael Kors  CATALONIA MK1144B
# 198  Dolce & Gabbana             DG4471
# 199  Dolce & Gabbana             DG4471
#
#                                            Description    Price Polarized  \
# 0                       Gold/Light Purple Brown Lenses  $538.20       Yes
# 1                       Honey Havana/Dark Brown Lenses  $509.40       Yes
# 2                                  Brass/Violet Lenses  $501.30       Yes
# 3                 Pale Gold/Brown Grey Gradient Lenses  $592.20       Yes
# 4                          Silver/Grey Gradient Lenses  $592.20       Yes
# ..                                                 ...      ...       ...
# 195             Shiny Light Gold/Brown Gradient Lenses  $253.80       Yes
# 196  Shiny Rose Gold/Light Brown and Pink Gradient ...  $253.80       Yes
# 197             Shiny Light Gold/Brown Gradient Lenses  $253.80       Yes
# 198  Transparent Violet/Lilac Isa Black Silver Mirr...  $413.10       Yes
# 199                             Black/Dark Grey Lenses  $413.10       Yes
#
#               Prescription
# 0    Prescribed Sunglasses
# 1    Prescribed Sunglasses
# 2    Prescribed Sunglasses
# 3    Prescribed Sunglasses
# 4    Prescribed Sunglasses
# ..                     ...
# 195  Prescribed Sunglasses
# 196  Prescribed Sunglasses
# 197  Prescribed Sunglasses
# 198  Prescribed Sunglasses
# 199  Prescribed Sunglasses
#
# [200 rows x 6 columns]

# %%
df.to_csv('test_data/ploarized_prescribed_sunglasses.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# 2. No polarized No prescibed

# %%
df = pd.read_csv('prod_no_polarized_no_prescribed_glasses.csv')
df.head()
# Out:
#             Brand Product Name          Description    Price
# 0  Bottega Veneta      BV1325S    Black/Grey Lenses  $655.00
# 1  Bottega Veneta      BV1319S    Black/Grey Lenses  $620.00
# 2  Bottega Veneta      BV1319S  Havana/Brown Lenses  $620.00
# 3  Bottega Veneta      BV1005S    Black/Grey Lenses  $725.00
# 4           Chloe      CH0259S   Black/Brown Lenses  $661.50

# %%
df['Polarized'] = 'No'
df['Prescription'] = 'No'

# %%
df.head()
# Out:
#             Brand Product Name          Description    Price Polarized  \
# 0  Bottega Veneta      BV1325S    Black/Grey Lenses  $655.00        No
# 1  Bottega Veneta      BV1319S    Black/Grey Lenses  $620.00        No
# 2  Bottega Veneta      BV1319S  Havana/Brown Lenses  $620.00        No
# 3  Bottega Veneta      BV1005S    Black/Grey Lenses  $725.00        No
# 4           Chloe      CH0259S   Black/Brown Lenses  $661.50        No
#
#   Prescription
# 0           No
# 1           No
# 2           No
# 3           No
# 4           No

# %%
df.to_csv('test_data/no_polarized_no_prescribed.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# 3. No polarized Prescribed Sunglasses

# %%
df1 = pd.read_csv('prod_no_polarized_prescribed.csv')
df2 = pd.read_csv('prod_no_polarized_prescribed_1.csv')

df = pd.concat([df1, df2], ignore_index=True)

# %%
df.head()
# Out:
#      Brand Product Name                           Description    Price
# 0  Miu Miu       MU56ZS        Gold/Light Purple Brown Lenses  $538.20
# 1  Miu Miu         01YS        Honey Havana/Dark Brown Lenses  $509.40
# 2    Prada       PRA60S                   Brass/Violet Lenses  $501.30
# 3    Prada       PRA51S  Pale Gold/Brown Grey Gradient Lenses  $592.20
# 4    Prada       PRA51S           Silver/Grey Gradient Lenses  $592.20

# %%
df['Polarized'] = 'No'
df['Prescription'] = 'Prescribed Sunglasses'

# %%
df.to_csv('test_data/no_polarized_prescribed_sunglasses.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# 4. No polarized Prescibed Glasses

# %%
df1= pd.read_csv('prod_no_polarized_prescribed_glasses.csv')
df2 = pd.read_csv('prod_no_polarized_prescribed_glasses_1.csv')

df = pd.concat([df1, df2], ignore_index=True)

# %%
df.head()
# Out:
#              Brand       Product Name                           Description  \
# 0   Oakley Glasses  Enigma Ink OX8190  Satin Black/Clear Lenses 55 Eye Size
# 1  Ray-Ban Glasses         Kat RX7327        Lilac/Clear Lenses 50 Eye Size
# 2  Ray-Ban Glasses         Kat RX7327  Algae Green/Clear Lenses 50 Eye Size
# 3  Ray-Ban Glasses         Kat RX7327       Havana/Clear Lenses 50 Eye Size
# 4  Ray-Ban Glasses         Kat RX7327        Black/Clear Lenses 50 Eye Size
#
#      Price
# 0  $237.60
# 1  $169.20
# 2  $169.20
# 3  $169.20
# 4  $169.20

# %%
df['Polarized'] = 'No'
df['Prescription'] = 'Prescribed Glasses'

# %%
df.to_csv('test_data/no_polarized_prescribed_glasses.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# 5. Merge all the data

# %%
df1 = pd.read_csv('test_data/no_polarized_no_prescribed.csv')
df2 = pd.read_csv('test_data/no_polarized_prescribed_glasses.csv')
df3 = pd.read_csv('test_data/no_polarized_prescribed_sunglasses.csv')
df4 = pd.read_csv('test_data/ploarized_prescribed_sunglasses.csv')

df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df.shape
# Out:
# (700, 6)

# %%
# show the duplicated rows ['Brand', 'Product Name', 'Description', 'Price']
df[df.duplicated(subset=['Brand', 'Product Name', 'Description', 'Price'], keep=False)].sort_values(by=['Brand', 'Product Name', 'Description', 'Price']).head(30)
# Out:
#                Brand       Product Name  \
# 338     Bask Eyewear              Peggy
# 538     Bask Eyewear              Peggy
# 339     Bask Eyewear              Sandy
# 539     Bask Eyewear              Sandy
# 340     Bask Eyewear              Sandy
# 540     Bask Eyewear              Sandy
# 387            Bolle              Fenix
# 587            Bolle              Fenix
# 324            Coach            HC8391U
# 524            Coach            HC8391U
# 332  Dolce & Gabbana             DG4416
# 532  Dolce & Gabbana             DG4416
# 334  Dolce & Gabbana             DG4416
# 534  Dolce & Gabbana             DG4416
# 333  Dolce & Gabbana             DG4416
# 533  Dolce & Gabbana             DG4416
# 392  Dolce & Gabbana            DG4446B
# 592  Dolce & Gabbana            DG4446B
# 331  Dolce & Gabbana             DG4449
# 531  Dolce & Gabbana             DG4449
# 325   Emporio Armani             EA4219
# 525   Emporio Armani             EA4219
# 320     Michael Kors  Flatiron MK2185BU
# 520     Michael Kors  Flatiron MK2185BU
# 319     Michael Kors  Flatiron MK2185BU
# 519     Michael Kors  Flatiron MK2185BU
# 321     Michael Kors      Malta MK2181U
# 521     Michael Kors      Malta MK2181U
# 77           Miu Miu               01YS
# 301          Miu Miu               01YS
#
#                                          Description    Price Polarized  \
# 338         Tea Tort/Brown Gradient Polarised Lenses  $220.00        No
# 538         Tea Tort/Brown Gradient Polarised Lenses  $220.00       Yes
# 339             Black/Grey Gradient Polarised Lenses  $220.00        No
# 539             Black/Grey Gradient Polarised Lenses  $220.00       Yes
# 340                  Tea Tort/Brown Polarised Lenses  $220.00        No
# 540                  Tea Tort/Brown Polarised Lenses  $220.00       Yes
# 387    Matte Black/Phantom Brown Photochromic Lenses  $268.20        No
# 587    Matte Black/Phantom Brown Photochromic Lenses  $268.20       Yes
# 324                    Caramel Tortoise/Brown Lenses  $179.35        No
# 524                    Caramel Tortoise/Brown Lenses  $179.35       Yes
# 332                                Black/Grey Lenses  $334.80        No
# 532                                Black/Grey Lenses  $334.80       Yes
# 334                         Havana/Dark Brown Lenses  $334.80        No
# 534                         Havana/Dark Brown Lenses  $334.80       Yes
# 333                         Leopard/Dark Grey Lenses  $334.80        No
# 533                         Leopard/Dark Grey Lenses  $334.80       Yes
# 392                                Black/Grey Lenses  $504.90        No
# 592                                Black/Grey Lenses  $504.90       Yes
# 331    Havana and White Barrow/Brown Gradient Lenses  $382.50        No
# 531    Havana and White Barrow/Brown Gradient Lenses  $382.50       Yes
# 325                Matte Black/Grey Polarised Lenses  $264.35        No
# 525                Matte Black/Grey Polarised Lenses  $264.35       Yes
# 320      Black/Dark Grey Gradient Lenses 54 Eye Size  $253.80        No
# 520      Black/Dark Grey Gradient Lenses 54 Eye Size  $253.80       Yes
# 319  Dark Tortoise/Brown Gradient Lenses 54 Eye Size  $253.80        No
# 519  Dark Tortoise/Brown Gradient Lenses 54 Eye Size  $253.80       Yes
# 321      Black/Dark Grey Gradient Lenses 55 Eye Size  $166.50        No
# 521      Black/Dark Grey Gradient Lenses 55 Eye Size  $166.50       Yes
# 77                    Honey Havana/Dark Brown Lenses  $509.40        No
# 301                   Honey Havana/Dark Brown Lenses  $509.40        No
#
#               Prescription
# 338  Prescribed Sunglasses
# 538  Prescribed Sunglasses
# 339  Prescribed Sunglasses
# 539  Prescribed Sunglasses
# 340  Prescribed Sunglasses
# 540  Prescribed Sunglasses
# 387  Prescribed Sunglasses
# 587  Prescribed Sunglasses
# 324  Prescribed Sunglasses
# 524  Prescribed Sunglasses
# 332  Prescribed Sunglasses
# 532  Prescribed Sunglasses
# 334  Prescribed Sunglasses
# 534  Prescribed Sunglasses
# 333  Prescribed Sunglasses
# 533  Prescribed Sunglasses
# 392  Prescribed Sunglasses
# 592  Prescribed Sunglasses
# 331  Prescribed Sunglasses
# 531  Prescribed Sunglasses
# 325  Prescribed Sunglasses
# 525  Prescribed Sunglasses
# 320  Prescribed Sunglasses
# 520  Prescribed Sunglasses
# 319  Prescribed Sunglasses
# 519  Prescribed Sunglasses
# 321  Prescribed Sunglasses
# 521  Prescribed Sunglasses
# 77                      No
# 301  Prescribed Sunglasses

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Ray-Ban                      105
# Oakley                        65
# Ray-Ban Glasses               58
# Prada                         45
# Prada Glasses                 36
# Michael Kors                  29
# Versace Glasses               26
# Valley Eyewear                25
# Emporio Armani                24
# Burberry Glasses              23
# Miu Miu                       23
# Coach                         20
# GUCCI                         17
# Prada Linea Rossa Glasses     16
# Persol                        13
# Boss                          12
# Dolce & Gabbana               12
# Oakley Glasses                12
# Raen                          10
# Oakley Youth                   9
# Versace                        9
# Tiffany & Co. Glasses          9
# Isabel Marant                  9
# Arnette                        8
# Serengeti                      8
# Miu Miu Glasses                7
# Persol Glasses                 7
# Polo Ralph Lauren              7
# Bask Eyewear                   6
# Prada Linea Rossa              6
# AM Eyewear                     6
# Dirty Dog                      6
# Saint Laurent                  5
# Giorgio Armani                 5
# Bottega Veneta                 4
# Michael Kors Glasses           3
# Dolce & Gabbana Glasses        3
# Cancer Council Kids            3
# Chloe                          2
# Bolle                          2
# Locello                        2
# OTIS                           2
# Epokhe                         1
# Name: count, dtype: int64

# %%
# remove the brand that has value count less than 8 
df = df[df.groupby('Brand').Brand.transform('count') > 7]

# %%
df.shape
# Out:
# (649, 6)

# %%
df.Brand.value_counts()
# Out:
# Brand
# Ray-Ban              163
# Prada                 81
# Oakley                77
# Versace               35
# Michael Kors          32
# Miu Miu               30
# Valley Eyewear        25
# Emporio Armani        24
# Burberry              23
# Prada Linea Rossa     22
# Coach                 20
# Persol                20
# GUCCI                 17
# Dolce & Gabbana       15
# Boss                  12
# Raen                  10
# Isabel Marant          9
# Tiffany & Co.          9
# Oakley Youth           9
# Serengeti              8
# Arnette                8
# Name: count, dtype: int64

# %%
df['Brand'] = df['Brand'].str.replace('Glasses', '').str.strip()
df['Brand'] = df['Brand'].str.replace('Eyewear', '').str.strip()

# %%
df.Brand.value_counts()
# Out:
# Brand
# Ray-Ban              163
# Prada                 81
# Oakley                77
# Versace               35
# Michael Kors          32
# Miu Miu               30
# Valley                25
# Emporio Armani        24
# Burberry              23
# Prada Linea Rossa     22
# Coach                 20
# Persol                20
# GUCCI                 17
# Dolce & Gabbana       15
# Boss                  12
# Raen                  10
# Isabel Marant          9
# Tiffany & Co.          9
# Oakley Youth           9
# Serengeti              8
# Arnette                8
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     Brand Product Name                 Description    Price Polarized  \
# 6   GUCCI      GG1736S           Black/Grey Lenses  $575.00        No
# 7   GUCCI     GG1732SK           Black/Grey Lenses  $700.00        No
# 8   GUCCI      GG1719S           Black/Grey Lenses  $495.00        No
# 9   GUCCI      GG1719S           Red/Violet Lenses  $495.00        No
# 10  GUCCI      GG1714S  Black/Grey Gradient Lenses  $390.00        No
#
#    Prescription
# 6            No
# 7            No
# 8            No
# 9            No
# 10           No

# %%
# create 2 column by splitting the 'Description' column
# description column is splitted by / and the first part is stored in 'Frame Color' column and the second part is stored in 'Lense Color' column
df[['Frame Color', 'Lense Color']] = df['Description'].str.split('/', n=1, expand=True)

# %%
df['Lense Color'] = df['Lense Color'].str.replace('Lenses', '').str.strip()
df.drop('Description', axis=1, inplace=True)

# %%
df.rename(columns={'Product Name': 'Product_Name', 'Frame Color': 'Frame_Color', 'Lense Color': 'Lense_Color'}, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    Brand Product_Name    Price Polarized Prescription Frame_Color  \
# 0  GUCCI      GG1736S  $575.00        No           No       Black
# 1  GUCCI     GG1732SK  $700.00        No           No       Black
# 2  GUCCI      GG1719S  $495.00        No           No       Black
# 3  GUCCI      GG1719S  $495.00        No           No         Red
# 4  GUCCI      GG1714S  $390.00        No           No       Black
#
#      Lense_Color
# 0           Grey
# 1           Grey
# 2           Grey
# 3         Violet
# 4  Grey Gradient

# %%
df.to_csv('../data/product_details.csv', index=False, header=True)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/product_details.csv')

# %%
# Generate unique 8-digit item IDs
num_products = len(df)
unique_ids = np.random.choice(range(10000000, 100000000), num_products, replace=False)

# Assign the unique IDs to a new column
df['Item ID'] = unique_ids

# %%
df.to_csv('../data/product_details.csv', index=False)

# %%
import pandas as pd

# %%
prod = pd.read_csv('../data/product_details.csv')

prod.head()
# Out:
#    Brand Product_Name  Price Polarized Prescription Frame_Color  \
# 0  GUCCI      GG1736S  575.0        No           No       Black
# 1  GUCCI     GG1732SK  700.0        No           No       Black
# 2  GUCCI      GG1719S  495.0        No           No       Black
# 3  GUCCI      GG1719S  495.0        No           No         Red
# 4  GUCCI      GG1714S  390.0        No           No       Black
#
#      Lense_Color Eye_Size   Item ID
# 0           Grey      NaN  67279410
# 1           Grey      NaN  53115940
# 2           Grey      NaN  15304140
# 3         Violet      NaN  31284680
# 4  Grey Gradient      NaN  30166194

# %%
prod.shape
# Out:
# (649, 9)

# %%
# I have some null values in the 'eye_size' column and I want to fill them with the value above them
# shuffle the dataframe
prod = prod.sample(frac=1).reset_index(drop=True)
prod.head()
# Out:
#      Brand    Product_Name  Price Polarized           Prescription  \
# 0  Ray-Ban  Aviator RX6489  201.6        No     Prescribed Glasses
# 1   Valley        Tomahawk  260.0        No  Prescribed Sunglasses
# 2   Oakley   Radar EV Path  333.9        No  Prescribed Sunglasses
# 3  Ray-Ban      Jim RB3694  219.6       Yes  Prescribed Sunglasses
# 4   Oakley       BiSphaera  300.6        No  Prescribed Sunglasses
#
#                  Frame_Color                           Lense_Color  \
# 0                     Silver                               Clear
# 1  Crystal with Silver Metal                                 Black
# 2             Matte Grey Ink            Prizm Deep Water Polarised
# 3         Havana on Gunmetal  Vintage Brown Black Gradient Glass
# 4               Matte Carbon                                Prizm
#
#                Eye_Size   Item ID
# 0           55 Eye Size  79189032
# 1                   NaN  39878751
# 2                   NaN  39775104
# 3           55 Eye Size  31485446
# 4  24K Mirror Polarised  61448395

# %%
prod['Eye_Size'].fillna(method='ffill', inplace=True)
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_14292\2759714469.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   prod['Eye_Size'].fillna(method='ffill', inplace=True)
# C:\Users\ayush\AppData\Local\Temp\ipykernel_14292\2759714469.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   prod['Eye_Size'].fillna(method='ffill', inplace=True)

# %%
prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         649 non-null    object
#  1   Product_Name  649 non-null    object
#  2   Price         649 non-null    float64
#  3   Polarized     649 non-null    object
#  4   Prescription  649 non-null    object
#  5   Frame_Color   649 non-null    object
#  6   Lense_Color   649 non-null    object
#  7   Eye_Size      649 non-null    object
#  8   Item ID       649 non-null    int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 45.8+ KB

# %%
prod.to_csv('../data/product.csv', index=False)
