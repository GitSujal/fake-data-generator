# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ayush\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ayush\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ayush\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# load the data
data = pd.read_csv('../data/merged_data.csv')

# %%
data.head()
# Out:
#    user_id first_name  last_name                          email  age  gender  \
# 0  8356259      James      Salas       James.Salas.DDS@ross.net   42    Male
# 1  6612383    Rebecca  Patterson     Rebecca.Patterson@wade.net   61    Male
# 2  3844909     Meagan       Kirk  Meagan.Kirk@carey-manning.org   69  Female
# 3  3094472       Leah   Mitchell    Leah.Mitchell@fisher.com.au   33  Female
# 4  6234966      Katie   Richards      Katie.Richards@wilson.biz   20  Female
#
#    postcode    country   item_id         action            brand product_name  \
# 0      3720  Australia  43796976  added_to_cart          Versace    1739/F/SK
# 1      3059  Australia  96224516         viewed            Prada       PRA08V
# 2      2582  Australia  46937700      purchased          Ray-Ban   Kat RX7327
# 3      4892  Australia  68796712  added_to_cart  Dolce & Gabbana       PR15WS
# 4      6323  Australia  63577055  added_to_cart           Valley       VE3338
#
#    eye_size              lens_color price_range polarized_glasses  \
# 0        56                   Clear      medium                No
# 1        50                 Clear        medium                No
# 2        56                   Clear      medium                No
# 3        57                   Clear      medium                No
# 4        61  Dark Green Polarised          high                No
#
#   prescribed_glasses
# 0                Yes
# 1                Yes
# 2                Yes
# 3                 No
# 4                Yes

# %%
data.shape
# Out:
# (97814, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97814 entries, 0 to 97813
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             97814 non-null  int64
#  1   first_name          97814 non-null  object
#  2   last_name           97814 non-null  object
#  3   email               97814 non-null  object
#  4   age                 97814 non-null  int64
#  5   gender              97814 non-null  object
#  6   postcode            97814 non-null  int64
#  7   country             97814 non-null  object
#  8   item_id             97814 non-null  int64
#  9   action              97814 non-null  object
#  10  brand               97814 non-null  object
#  11  product_name        97814 non-null  object
#  12  eye_size            97814 non-null  int64
#  13  lens_color          97814 non-null  object
#  14  price_range         97814 non-null  object
#  15  polarized_glasses   97814 non-null  object
#  16  prescribed_glasses  97814 non-null  object
# dtypes: int64(5), object(12)
# memory usage: 12.7+ MB

# %%
data.eye_size.unique()
# Out:
# array([56, 50, 57, 61, 51, 55, 54, 58, 62, 52, 53, 59, 60, 48])

# %%
new_data = data.sample(10000).reset_index(drop=True)

# %%
new_data['tags'] = new_data.apply(lambda row: f"{row['age']} {row['gender']} {row['item_id']} {row['brand']} {row['product_name']} {row['eye_size']} {row['lens_color']} {row['price_range']} {row['polarized_glasses']} {row['prescribed_glasses']} {row['action']}", axis=1)

# %%
new_df = new_data[['user_id', 'tags']]

# %%
new_df.head()
# Out:
#    user_id                                               tags
# 0  4304335  52 Female 35245781 Persol RB2206D 52 Clear med...
# 1  1770875  60 Female 19737001 Oakley PR02ZV 53 Dark Brown...
# 2  1594668  63 Male 76512214 Oakley VE3339U 53 Prizm Black...
# 3  4758511  70 Male 45682106 Ray-Ban Ritual 61 Black Gradi...
# 4  2093188  29 Female 94587352 Isabel Marant BE1386 57 Cle...

# %%
# preprocess the tags column
def preprocess_text(text):
    try:
        # Convert to lowercase
        text = text.lower()

        # lemmatizer
        lemmatizer = WordNetLemmatizer()

        # Define stopwords
        stop_words = set(stopwords.words('english'))
        
        # Remove special characters
        text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
        
        # Tokenize the text
        tokens = word_tokenize(text)
        
        # Remove stopwords and lemmatize
        tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
        
        # Join tokens back into a single string
        processed_text = ' '.join(tokens)
        
        return processed_text
    
    except Exception as e:
        print(e)
        return None

# %%
# Apply the preprocessing function to the 'tags' column
new_df['tags'] = new_df['tags'].apply(preprocess_text)

# %%
new_df.shape
# Out:
# (10000, 2)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  10000 non-null  int64
#  1   tags     10000 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 156.4+ KB

# %%
new_df.head()
# Out:
#    user_id                                               tags
# 0  4304335  52 female 35245781 persol rb2206d 52 clear med...
# 1  1770875  60 female 19737001 oakley pr02zv 53 dark brown...
# 2  1594668  63 male 76512214 oakley ve3339u 53 prizm black...
# 3  4758511  70 male 45682106 rayban ritual 61 black gradie...
# 4  2093188  29 female 94587352 isabel marant be1386 57 cle...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=50)
tfidf_matrix = vectorizer.fit_transform(new_df['tags'])

# %%
similarity = cosine_similarity(tfidf_matrix)

# %%
similarity[10]
# Out:
# array([0.35848546, 0.25041313, 0.30656055, ..., 0.37047706, 0.21690194,
#        0.06178817])

# %%
# extract the top 5 similar glasses for provided user_id
def get_top_similar_glasses(user_id: int, similarity, top_n=5):
    # Check if user_id exists in the new_data
    if user_id not in new_data['user_id'].values:
        return f"User ID {user_id} not found in the data."
    
    # Get the index of the user_id
    idx = new_data[new_data['user_id'] == user_id].index[0]
    
    # Get the similarity scores of the user_id with the products they have interacted with
    similar_glasses = list(enumerate(similarity[idx]))

    # Sort the similar glasses based on the similarity scores
    similar_glasses = sorted(similar_glasses, key=lambda x: x[1], reverse=True)

    # Get the top 5 similar glasses
    top_similar_glasses = similar_glasses[1:top_n+1]

    # Get the product details like brand name, product_name, frame_color, lens_color, price_range
    product_details = []
    for i in top_similar_glasses:
        idx = i[0]
        processed_tags = new_data.loc[idx, ['item_id', 'brand', 'product_name', 'lens_color', 'price_range', 'eye_size', 'polarized_glasses', 'prescribed_glasses']]
        product_details.append(processed_tags)
        
    return product_details

# %%
recommendations= get_top_similar_glasses(1243730, similarity, top_n=10)

recommendations = pd.DataFrame(recommendations, columns=['item_id', 'brand', 'product_name', 'lens_color', 'price_range', 'eye_size', 'polarized_glasses', 'prescribed_glasses'])

# %%
recommendations
# Out:
#        item_id    brand           product_name  \
# 8654  49452138  Ray-Ban      Mr Burbank RX5383
# 5464  72385789  Ray-Ban  New Clubmaster RX7216
# 9907  35813480  Ray-Ban                 RB4435
# 4330  41905800  Ray-Ban                 PRA09S
# 8418  32301501  Ray-Ban               Feedback
# 633   12367608  Ray-Ban                 PS07PV
# 8193  97914656  Ray-Ban          Phoxer AN4338
# 5770  15548150  Ray-Ban                 RX7228
# 5120  59612289  Ray-Ban     Bain Bridge RB3735
# 4985  48376464  Ray-Ban                 RB4435
#
#                           lens_color price_range  eye_size polarized_glasses  \
# 8654         Green Polarised Glass          high        50                No
# 5464         Green Glass Polarised          high        59                No
# 9907         Green Polarised Glass        medium        59               Yes
# 4330  Green Vintage Gradient Glass          high        59                No
# 8418                   Green Glass        medium        59               Yes
# 633                    Green Glass        medium        59                No
# 8193                 Green Polarised      medium        59                No
# 5770          Dark Green Polarised        medium        59                No
# 5120                   Green Glass        medium        54                No
# 4985         Green Polarised Glass        medium        59                No
#
#      prescribed_glasses
# 8654                 No
# 5464                 No
# 9907                 No
# 4330                Yes
# 8418                 No
# 633                  No
# 8193                 No
# 5770                Yes
# 5120                 No
# 4985                 No

# %%
data[(data['user_id'] == 1243730)].sort_values(by=['action', 'brand'], ascending=False).head(50)
# Out:
#        user_id first_name last_name                   email  age  gender  \
# 38594  1243730     Rhonda     James  Rhonda.James@tapia.com   42  Female
# 48012  1243730     Rhonda     James  Rhonda.James@tapia.com   42  Female
# 32270  1243730     Rhonda     James  Rhonda.James@tapia.com   42  Female
# 94253  1243730     Rhonda     James  Rhonda.James@tapia.com   42  Female
# 54733  1243730     Rhonda     James  Rhonda.James@tapia.com   42  Female
# 32223  1243730     Rhonda     James  Rhonda.James@tapia.com   42  Female
# 45972  1243730     Rhonda     James  Rhonda.James@tapia.com   42  Female
# 28649  1243730     Rhonda     James  Rhonda.James@tapia.com   42  Female
# 56434  1243730     Rhonda     James  Rhonda.James@tapia.com   42  Female
# 78122  1243730     Rhonda     James  Rhonda.James@tapia.com   42  Female
#
# 54733              PRA59S        55                               Brown
# 32223     Bel Air MK2209U        54                        Brown Mirror
# 45972       Dubai MK2211U        55            Brown Gradient Polarised
# 28649              PR26ZS        56                               Clear
# 56434              PRA03V        56                       Green Glass
# 78122             GG1680S        54                             Clear
# 80989  Bain Bridge RB3735        56                          Prizm Golf
# 85217           BiSphaera        56                          Prizm Golf
# 87703  Bain Bridge RB3735        56             Green Polarised Glass
# 4141      Bel Air MK2209U        55                        Brown Mirror
# 10975             Shelton        58                             Clear
# 16824  Bain Bridge RB3735        56                          Prizm Golf
# 49539         Nice MK2213        56                      Brown Gradient
# 56875              PR23YS        58                             Clear
# 79874              RX7228        58                             Clear
# 90656              BE1386        56                             Clear
# 22315             PO3328S        58     Blue Gradient Polarised Glass
# 43804              DG4416        58                         Olive Green
# 84958              BE1386        58                             Clear
# 13199              PRA59S        55                          Prizm Road
# 34563  Old Aviator RB3825        54                             Clear
# 29705              PRA03V        56          Brown Gradient Polarised
# 37830   Asheville MK2210U        56                             Clear
# 50424              PRA03V        56          Brown Gradient Polarised
# 64990              BE2388        53                       Green Glass
# 65948              BE1386        58                             Clear
# 10619              PR26ZS        59             Green Polarised Glass
# 23192      Aviator RX6489        54                             Clear
# 44997         Zena RX7330        54                             Clear
# 94693              PR26ZS        56             Green Polarised Glass
# 12157         Nice MK2213        56                         Prizm Slate
# 36124              PRA03V        56                               Clear
# 36466                05VV        55                             Clear
# 40806              PR23YS        58                             Clear
# 47359         Nice MK2213        56                      Brown Gradient
# 50654  Old Aviator RB3825        58                             Clear
# 1985         Erika RX7046        58                         Olive Green
# 13632              BE2388        53       Blue Gradient Polarised Glass
# 14639             PO3328S        58                         Olive Green
# 79276           BiSphaera        56                          Prizm Golf
# 3265      Bel Air MK2209U        55                        Brown Mirror
# 38310              PRA03V        56                             Clear
# 69901              PRA59S        55                         Olive Green
# 39400             HC8395F        53                       Green Glass
# 51316              BE2388        53                       Green Glass
# 96805             HC8395F        56                       Green Glass
#
#       price_range polarized_glasses prescribed_glasses
# 38594        high               Yes                 No
# 48012        high               Yes                 No
# 32270        high                No                 No
# 94253      medium                No                 No
# 54733      medium                No                 No
# 32223        high               Yes                 No
# 45972      medium                No                 No
# 28649        high                No                 No
# 56434        high               Yes                 No
# 78122        high               Yes                 No
# 80989      medium                No                 No
# 85217      medium                No                 No
# 87703        high               Yes                 No
# 4141       medium                No                 No
# 10975        high               Yes                 No
# 16824        high                No                 No
# 49539      medium               Yes                 No
# 56875      medium               Yes                 No
# 79874      medium               Yes                 No
# 90656        high                No                 No
# 22315        high               Yes                 No
# 43804        high                No                 No
# 84958      medium                No                 No
# 13199      medium                No                 No
# 34563      medium               Yes                 No
# 29705        high               Yes                 No
# 37830      medium               Yes                 No
# 50424        high               Yes                 No
# 64990        high               Yes                 No
# 65948      medium                No                 No
# 10619        high                No                 No
# 23192      medium               Yes                 No
# 44997      medium               Yes                 No
# 94693        high                No                 No
# 12157      medium                No                 No
# 36124        high                No                 No
# 36466      medium                No                 No
# 40806      medium               Yes                 No
# 47359      medium                No                 No
# 50654        high               Yes                 No
# 1985       medium                No                 No
# 13632        high               Yes                 No
# 14639        high                No                 No
# 79276      medium                No                 No
# 3265       medium               Yes                 No
# 38310        high               Yes                 No
# 69901      medium                No                 No
# 39400        high               Yes                 No
# 51316        high               Yes                 No
# 96805        high               Yes                 No
